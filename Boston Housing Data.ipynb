# %% [markdown]
# # Capston Project-Boston house Pricing

# %% [markdown]
# # Importing Necessory Libraries

# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading the data

# %%
housing=pd.read_csv(r'C:\Users\faisal\Downloads\capston project\capstonprojectdata.csv')

# %% [markdown]
# # Checking the Top 5 rows of the dataset

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  ...  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296  ...
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242  ...
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242  ...
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222  ...
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222  ...
#
#    Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24
# ...

# %% [markdown]
# # Checking the Bottom 5 rows of the dataset

# %%
housing.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  ...  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273  ...
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273  ...
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273  ...
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273  ...
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273  ...
#
#      Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 501          NaN          NaN          NaN          NaN          NaN
# 502          NaN          NaN          NaN          NaN          NaN
# 503          NaN          NaN          NaN          NaN          NaN
# 504          NaN          NaN          NaN          NaN          NaN
# 505          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24
# ...

# %% [markdown]
# # Cleaning the Data by removing unnamed columns

# %%
housing=housing.loc[:, ~housing.columns.str.contains('^Unnamed')]

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# # checking the datatypes of the variable

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %% [markdown]
# # Describing the data, checking value counts,average,standard deviation and min,max

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# # Importing Matplotlib which is a plotting library for creating static, animated, and interactive visualizations in Python

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Creating histogram which represent data provided in a form of some groups

# %%
housing.hist(bins=50,figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'CRIM'}>,
#         <AxesSubplot:title={'center':'ZN'}>,
#         <AxesSubplot:title={'center':'INDUS'}>,
#         <AxesSubplot:title={'center':'CHAS'}>],
#        [<AxesSubplot:title={'center':'NOX'}>,
#         <AxesSubplot:title={'center':'RM'}>,
#         <AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'DIS'}>],
#        [<AxesSubplot:title={'center':'RAD'}>,
#         <AxesSubplot:title={'center':'TAX'}>,
#         <AxesSubplot:title={'center':'PTRATIO'}>,
#         <AxesSubplot:title={'center':'B'}>],
#        [<AxesSubplot:title={'center':'LSTAT'}>,
#         <AxesSubplot:title={'center':'MEDV'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
corr=housing.corr()
corr
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
import seaborn as sns
plt.figure(figsize=(40,35))
plt.title("correlatiom matrix")
sns.heatmap(corr,vmax=+1,vmin=-1,fmt='g',cmap='RdYlGn',annot=True)
plt.show()

# %%
corr_matrix=housing.corr()

# %%
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.695360
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# AGE       -0.376955
# RAD       -0.381626
# CRIM      -0.388305
# NOX       -0.427321
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes=['MEDV','RM','ZN','LSTAT']
scatter_matrix(housing[attributes],figsize=(12,8))
# Out:
# array([[<AxesSubplot:xlabel='MEDV', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='RM', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='ZN', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='RM'>,
#         <AxesSubplot:xlabel='RM', ylabel='RM'>,
#         <AxesSubplot:xlabel='ZN', ylabel='RM'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='RM'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='ZN'>,
#         <AxesSubplot:xlabel='RM', ylabel='ZN'>,
#         <AxesSubplot:xlabel='ZN', ylabel='ZN'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='ZN'>],
#        [<AxesSubplot:xlabel='MEDV', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='RM', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='ZN', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
housing.plot(kind='scatter',x='RM',y='MEDV',alpha=0.9)
# Out:
# <AxesSubplot:xlabel='RM', ylabel='MEDV'>

# %% [markdown]
# # Train Test Splitting

# %%
x=housing.drop(['MEDV'],axis=1)
y=housing[['MEDV']]

# %% [markdown]
# #Dividing train test data in 80&20 percent ratio.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,train_size=0.8,random_state=15)

# %%
x_train.shape
# Out:
# (404, 13)

# %%
y_train.shape
# Out:
# (404, 1)

# %% [markdown]
# # selecting desired model

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Using Linear Regression

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
LR_pred = LR.predict(x_test)
print(r2_score(y_test,LR_pred)*100)
print(LR.score(x_test,y_test)*100)
print(LR.score(x_train,y_train)*100)
print(mean_squared_error(y_test,LR_pred))
# Out:
# 69.20749038652123
# 69.20749038652123
# 74.55344405641732
# 23.81224546508083

# %% [markdown]
# # using Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
RF=RandomForestRegressor(max_depth=30)
RF.fit(x_train,y_train)
RF_pred = RF.predict(x_test)
print(r2_score(y_test,RF_pred)*100)
print(RF.score(x_train,y_train)*100)
print(RF.score(x_test,y_test)*100)
print(mean_squared_error(y_test,RF_pred))
# Out:
# 85.88153782173882
# 98.35592614318907
# 85.88153782173882
# 10.91798918627451

# %% [markdown]
# # Using Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
DT = DecisionTreeRegressor(max_depth=10)
DT.fit(x_train,y_train)
DT_pred = DT.predict(x_test)
print(r2_score(y_test,DT_pred)*100)
print(DT.score(x_train,y_train)*100)
print(DT.score(x_test,y_test)*100)
print(mean_squared_error(y_test,DT_pred))
# Out:
# 71.21701776387167
# 99.0863515926285
# 71.21701776387167
# 22.258251984883216

# %% [markdown]
# # Using KNeighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=3)
knn.fit(x_train,y_train)
knn_pred = knn.predict(x_test)
print(r2_score(y_test,knn_pred)*100)
print(knn.score(x_train,y_train)*100)
print(knn.score(x_test,y_test)*100)
print(mean_squared_error(y_test,knn_pred))
# Out:
# 55.322688041768586
# 77.67706816693837
# 55.322688041768586
# 34.549542483660126

# %% [markdown]
#  # Using AdaBoost Regressor

# %%
from sklearn.ensemble import AdaBoostRegressor
AD = AdaBoostRegressor(n_estimators=100)
AD.fit(x_train,y_train)
AD_pred = AD.predict(x_test)
print(r2_score(y_test,AD_pred)*100)
print(AD.score(x_train,y_train)*100)
print(AD.score(x_test,y_test)*100)
print(mean_squared_error(y_test,AD_pred))
# Out:
# 79.9848032666968
# 91.30200109538058
# 79.9848032666968
# 15.478010192344804

# %% [markdown]
# # Using Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
GB = GradientBoostingRegressor(n_estimators=100)
GB.fit(x_train,y_train)
gb_pred = GB.predict(x_test)
print(r2_score(y_test,gb_pred)*100)
print('train accuracy:',GB.score(x_train,y_train)*100)
print('test accuracy:',GB.score(x_test,y_test)*100)
print(mean_squared_error(y_test,gb_pred))
# Out:
# 85.24903714442485
# train accuracy: 98.11154740863745
# test accuracy: 85.24903714442485
# 11.407110130753729

# %% [markdown]
# # Using XGB Regressor

# %%
from xgboost import XGBRegressor
XGB = XGBRegressor()
XGB.fit(x_train,y_train)
xgb_pred = XGB.predict(x_test)
print(r2_score(y_test,xgb_pred)*100)
print('train accuracy:',XGB.score(x_train,y_train)*100)
print('test accuracy:',XGB.score(x_test,y_test)*100)
print(mean_squared_error(y_test,xgb_pred))
# Out:
# 86.09119209981645
# train accuracy: 99.99949342089928
# test accuracy: 86.09119209981645
# 10.755860824700372

# %% [markdown]
# # Using LGBM Regressor

# %%
import lightgbm as lgbm
LG= lgbm.LGBMRegressor()
LG.fit(x_train,y_train)
lg_pred = LG.predict(x_test)
print(r2_score(y_test,lg_pred)*100)
print('train accuracy:',LG.score(x_train,y_train))
print('test accuracy:',LG.score(x_test,y_test))
print(mean_squared_error(y_test,lg_pred))
# Out:
# 85.48655217916051
# train accuracy: 0.9773818197210375
# test accuracy: 0.8548655217916051
# 11.223436686147668

# %% [markdown]
# # After Using all algorithms,Comparing their Accuracy to choose best algorithm

# %%
a=[['1. LinearRegression','2. Random Forest','3. Decision Tree','4. KNN','5. Ada Boost','5. Gradient Boosting','6. XG Boost','7. LGBM'],
   [LR.score(x_train,y_train),RF.score(x_train,y_train),DT.score(x_train,y_train),knn.score(x_train,y_train),AD.score(x_train,y_train),GB.score(x_train,y_train),XGB.score(x_train,y_train),LG.score(x_train,y_train)],
  [LR.score(x_test,y_test),RF.score(x_test,y_test),DT.score(x_test,y_test),knn.score(x_test,y_test),AD.score(x_test,y_test),GB.score(x_test,y_test),XGB.score(x_test,y_test),LG.score(x_test,y_test)]]

# %%
b=pd.DataFrame(a)

# %%
b.T
# Out:
#                       0         1         2
# 0   1. LinearRegression  0.745534  0.692075
# 1      2. Random Forest  0.983559  0.858815
# 2      3. Decision Tree  0.990864   0.71217
# 3                4. KNN  0.776771  0.553227
# 4          5. Ada Boost   0.91302  0.799848
# 5  5. Gradient Boosting  0.981115   0.85249
# 6           6. XG Boost  0.999995  0.860912
# 7               7. LGBM  0.977382  0.854866

# %% [markdown]
# # conclusion
# ##After comparing all the models that are Linear regression,random forest,decision tree, knn, adboost, gradient boosting, xg boost and Lgbm i came up with the conclusion that the XGB Regressor is the best model for this dataset because it has the highest accuracy of training-99% and testing-86% with lowest mean squared error that is 10.7
